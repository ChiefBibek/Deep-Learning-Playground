# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cgpa_resume_score_placed.csv')

# %%
print(df.shape)
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    CGPA  Resume Score  Placed
# 0   7.5            91       1
# 1   9.8            98       1
# 2   8.9            91       1
# 3   8.4            63       0
# 4   6.6            89       0

# %%
sns.scatterplot(data=df, x='CGPA', y='Resume Score', hue='Placed')
# Out:
# <Axes: xlabel='CGPA', ylabel='Resume Score'>

# %%
df["Resume Score"] = df["Resume Score"]/10

# %%
sns.scatterplot(x='CGPA', y='Resume Score', hue='Placed', data=df, palette='bwr', s=50)
# Out:
# <Axes: xlabel='CGPA', ylabel='Resume Score'>

# %%
df.head()
# Out:
#    CGPA  Resume Score  Placed
# 0   7.5           9.1       1
# 1   9.8           9.8       1
# 2   8.9           9.1       1
# 3   8.4           6.3       0
# 4   6.6           8.9       0

# %%
x = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(x, y)
# Out:
# Perceptron()

# %%
p.coef_, p.intercept_
# Out:
# (array([[1.8, 1.1]]), array([-42.]))

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x, y, clf=p, legend=2)
# Out:
# <Axes: >

# %%
from mlxtend.plotting import plot_decision_regions

import matplotlib.pyplot as plt

plot_decision_regions(x, y, clf=p, legend=2, zoom_factor=0.01)
plt.xlabel('CGPA')
plt.ylabel('Resume Score')
plt.title('Decision Regions')
plt.show()

# %%
x.shape , y.shape
# Out:
# ((100, 2), (100,))

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x[:, 0], x[:, 1], c=y, cmap='winter', s=100)
